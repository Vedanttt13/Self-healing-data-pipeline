# %%
import os
import sys
import json

sys.path.append(
    os.path.abspath("..")
)

from pyspark.sql import SparkSession

from heal import CodeMaster
from dataio import DataWriter
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 11
#       7 )
#       8
#       9 from pyspark.sql import SparkSession
#      10
# ---> 11 from heal.code_master import CodeMaster
#      12 from dataio.write_data import DataWriter
#
# File ~/Projects/Self-healing-data-pipeline/heal/__init__.py:1
# ----> 1 from .code_master import CodeMaster
#       2 from .heal_data import HealData
#
# File ~/Projects/Self-healing-data-pipeline/heal/code_master.py:3
#       1 import logging
#       2 from pyspark.sql import functions as F
# ----> 3 from heal_data import HealData
#       5 logging.basicConfig(
#       6     level=logging.INFO,
#       7     format="%(asctime)s - %(levelname)s - %(message)s"
#       8 )
#      10 logger = logging.getLogger(__name__)
#
# ModuleNotFoundError: No module named 'heal_data'

# %%
spark = (

    SparkSession.builder

    .appName(
        "SelfHealingPipeline"
    )

    .master("local[*]")

    .getOrCreate()

)

print("Spark Started")

# %%
with open(
        "../config/test_rules.json"
) as f:

    rules = json.load(f)


with open(
        "../config/test_source.json"
) as f:

    source = json.load(f)


print("Configs loaded")

# %%
csv_path = source["source"]["path"]

df = (

    spark.read

    .option(
        "header",
        True
    )

    .option(
        "inferSchema",
        True
    )

    .csv(csv_path)

)

print(
    "\nInput Data"
)

df.show(
    truncate=False
)

# %%
pipeline = CodeMaster(

        rules_dict=rules,

        input_data=df,

        spark=spark

)

results = pipeline.run()

# %%
clean_df = results[0]

healed_df = results[1]

rejected_df = results[2]

# %%
print(
"\n========== CLEAN =========="
)

clean_df.show(
truncate=False
)


print(
"\n========== HEALED =========="
)

healed_df.show(
truncate=False
)


print(
"\n========== REJECTED =========="
)

rejected_df.show(
truncate=False
)

# %%
writer = DataWriter(

        config=source,

        spark=spark

)


writer.data_write(
    clean_df,
    "clean"
)

writer.data_write(
    healed_df,
    "healed"
)

writer.data_write(
    rejected_df,
    "rejected"
)


print(
"\nFiles written successfully"
)


###########################################
# Verify Saved Outputs
###########################################

saved = spark.read.csv(

        "../output/healed",

        header=True

)

print(
"\nSaved healed data:"
)

saved.show(
truncate=False
)


###########################################
# Stop Spark
###########################################

spark.stop()

print(
"\nPipeline Completed"
)
